# %%
# !pip install pyreadstat
import pandas as pd
import pyreadstat
# Out:
# ...
#    HH1  HH2   LN  UF1  UF2  UFINT  UF3  UF4    UF5  UF6  ...  windex5u  \
# 0  1.0  1.0  5.0  1.0  1.0  104.0  5.0  4.0  104.0  1.0  ...       NaN
# 1  1.0  3.0  5.0  1.0  3.0  104.0  5.0  2.0  104.0  1.0  ...       NaN
# 2  1.0  3.0  6.0  1.0  3.0  104.0  6.0  2.0  104.0  1.0  ...       NaN
# 3  1.0  4.0  5.0  1.0  4.0  105.0  5.0  4.0  105.0  1.0  ...       NaN
# 4  1.0  4.0  6.0  1.0  4.0  105.0  6.0  4.0  105.0  1.0  ...       NaN
#
#    windex10u   wscorer  windex5r  windex10r  chweight  caretakerdis  \
# 0        NaN -1.226030       1.0        1.0   1.79871           2.0
# 1        NaN -0.976296       1.0        2.0   1.79871           2.0
# 2        NaN -0.976296       1.0        2.0   1.79871           2.0
# 3        NaN -0.567618       2.0        4.0   1.79871           2.0
# 4        NaN -0.567618       2.0        4.0   1.79871           2.0
#
#    caretakerdis2  stratum  psu
# 0            2.0     46.0  1.0
# 1            2.0     46.0  1.0
# 2            2.0     46.0  1.0
# ...

# %%
hh,meta=pyreadstat.read_sav("hh.sav")
ch, meta = pyreadstat.read_sav("ch.sav")
wm,meta=pyreadstat.read_sav("wm.sav")
ch.head()
wm.head()
ch.head()
type(hh)
type(ch.iloc[3])
# Out:
# pandas.core.series.Series
